# %%
# requirments
import numpy as np
import matplotlib.pyplot as plt
from nansat import Nansat, Domain
#from boreali import Boreali, lm
import csv
import os
from IPython.display import Image
from toolbox import show_it

# %matplotlib nbagg

# %%
test_img = Nansat('data/A2012242185000.L2_LAC_OC.nc')
test_img.reproject(dom, eResampleAlg=0)

# %%
test_img
# Out:
# ----------------------------------------
# data/A2012242185000.L2_LAC_OC.nc
# ----------------------------------------
# Mapper: obpg_l2_nc
# ----------------------------------------
# Band : 1 Kd_490
#   units: m^-1
#   name: Kd_490
#   dataType: 6
#   valid_min: 50
#   long_name: Diffuse attenuation coefficient at 490 nm, KD2 algorithm
#   standard_name: diffuse_attenuation_coefficient_of_downwelling_radiative_flux_in_sea_water
#   SourceFilename: /vsimem/5WQEEIVJM3.vrt
#   SourceBand: 1
#   valid_max: 30000
#   wkv: diffuse_attenuation_coefficient_of_downwelling_radiative_flux_in_sea_water
# Band : 2 Rrs_412
#   units: sr^-1
#   colormap: jet
#   short_name: Rrs
#   dataType: 6
#   valid_min: -30000
#   long_name: Remote sensing reflectance at 412 nm
#   standard_name: surface_ratio_of_upwelling_radiance_emerging_from_sea_water_to_downwelling_radiative_flux_in_air
#   SourceFilename: /vsimem/5WQEEIVJM3.vrt
#   minmax: 0.000 0.05
#   SourceBand: 2
#   wkv: surface_ratio_of_upwelling_radiance_emerging_from_sea_water_to_downwelling_radiative_flux_in_air
#   valid_max: 25000
#   solar_irradiance: 1711.8177
#   name: Rrs_412
# Band : 3 Rrs_443
#   units: sr^-1
#   colormap: jet
#   short_name: Rrs
#   dataType: 6
#   valid_min: -30000
#   long_name: Remote sensing reflectance at 443 nm
#   standard_name: surface_ratio_of_upwelling_radiance_emerging_from_sea_water_to_downwelling_radiative_flux_in_air
#   SourceFilename: /vsimem/5WQEEIVJM3.vrt
#   minmax: 0.000 0.05
#   SourceBand: 3
#   wkv: surface_ratio_of_upwelling_radiance_emerging_from_sea_water_to_downwelling_radiative_flux_in_air
#   valid_max: 25000
#   solar_irradiance: 1887.5414
#   name: Rrs_443
# Band : 4 Rrs_469
#   units: sr^-1
#   colormap: jet
#   short_name: Rrs
#   dataType: 6
#   valid_min: -30000
#   long_name: Remote sensing reflectance at 469 nm
#   standard_name: surface_ratio_of_upwelling_radiance_emerging_from_sea_water_to_downwelling_radiative_flux_in_air
#   SourceFilename: /vsimem/5WQEEIVJM3.vrt
#   minmax: 0.000 0.05
#   SourceBand: 4
#   wkv: surface_ratio_of_upwelling_radiance_emerging_from_sea_water_to_downwelling_radiative_flux_in_air
#   valid_max: 25000
#   solar_irradiance: 2035.2333
#   name: Rrs_469
# Band : 5 Rrs_488
#   units: sr^-1
#   colormap: jet
#   short_name: Rrs
#   dataType: 6
#   valid_min: -30000
#   long_name: Remote sensing reflectance at 488 nm
#   standard_name: surface_ratio_of_upwelling_radiance_emerging_from_sea_water_to_downwelling_radiative_flux_in_air
#   SourceFilename: /vsimem/5WQEEIVJM3.vrt
#   minmax: 0.000 0.05
#   SourceBand: 5
#   wkv: surface_ratio_of_upwelling_radiance_emerging_from_sea_water_to_downwelling_radiative_flux_in_air
#   valid_max: 25000
#   solar_irradiance: 1941.7841
#   name: Rrs_488
# Band : 6 Rrs_531
#   units: sr^-1
#   colormap: jet
#   short_name: Rrs
#   dataType: 6
#   valid_min: -30000
#   long_name: Remote sensing reflectance at 531 nm
#   standard_name: surface_ratio_of_upwelling_radiance_emerging_from_sea_water_to_downwelling_radiative_flux_in_air
#   SourceFilename: /vsimem/5WQEEIVJM3.vrt
#   minmax: 0.000 0.05
#   SourceBand: 6
#   wkv: surface_ratio_of_upwelling_radiance_emerging_from_sea_water_to_downwelling_radiative_flux_in_air
#   valid_max: 25000
#   solar_irradiance: 1859.4445
#   name: Rrs_531
# Band : 7 Rrs_547
#   units: sr^-1
#   colormap: jet
#   short_name: Rrs
#   dataType: 6
#   valid_min: -30000
#   long_name: Remote sensing reflectance at 547 nm
#   standard_name: surface_ratio_of_upwelling_radiance_emerging_from_sea_water_to_downwelling_radiative_flux_in_air
#   SourceFilename: /vsimem/5WQEEIVJM3.vrt
#   minmax: 0.000 0.05
#   SourceBand: 7
#   wkv: surface_ratio_of_upwelling_radiance_emerging_from_sea_water_to_downwelling_radiative_flux_in_air
#   valid_max: 25000
#   solar_irradiance: 1869.9834
#   name: Rrs_547
# Band : 8 Rrs_555
#   units: sr^-1
#   colormap: jet
#   short_name: Rrs
#   dataType: 6
#   valid_min: -30000
#   long_name: Remote sensing reflectance at 555 nm
#   standard_name: surface_ratio_of_upwelling_radiance_emerging_from_sea_water_to_downwelling_radiative_flux_in_air
#   SourceFilename: /vsimem/5WQEEIVJM3.vrt
#   minmax: 0.000 0.05
#   SourceBand: 8
#   wkv: surface_ratio_of_upwelling_radiance_emerging_from_sea_water_to_downwelling_radiative_flux_in_air
#   valid_max: 25000
#   solar_irradiance: 1837.5674
#   name: Rrs_555
# Band : 9 Rrs_645
#   units: sr^-1
#   colormap: jet
#   short_name: Rrs
#   dataType: 6
#   valid_min: -30000
#   long_name: Remote sensing reflectance at 645 nm
#   standard_name: surface_ratio_of_upwelling_radiance_emerging_from_sea_water_to_downwelling_radiative_flux_in_air
#   SourceFilename: /vsimem/5WQEEIVJM3.vrt
#   minmax: 0.000 0.05
#   SourceBand: 9
#   wkv: surface_ratio_of_upwelling_radiance_emerging_from_sea_water_to_downwelling_radiative_flux_in_air
#   valid_max: 25000
#   solar_irradiance: 1587.4379
#   name: Rrs_645
# Band : 10 Rrs_667
#   units: sr^-1
#   colormap: jet
#   short_name: Rrs
#   dataType: 6
#   valid_min: -30000
#   long_name: Remote sensing reflectance at 667 nm
#   standard_name: surface_ratio_of_upwelling_radiance_emerging_from_sea_water_to_downwelling_radiative_flux_in_air
#   SourceFilename: /vsimem/5WQEEIVJM3.vrt
#   minmax: 0.000 0.05
#   SourceBand: 10
#   wkv: surface_ratio_of_upwelling_radiance_emerging_from_sea_water_to_downwelling_radiative_flux_in_air
#   valid_max: 25000
#   solar_irradiance: 1524.3859
#   name: Rrs_667
# Band : 11 Rrs_678
#   units: sr^-1
#   colormap: jet
#   short_name: Rrs
#   dataType: 6
#   valid_min: -30000
#   long_name: Remote sensing reflectance at 678 nm
#   standard_name: surface_ratio_of_upwelling_radiance_emerging_from_sea_water_to_downwelling_radiative_flux_in_air
#   SourceFilename: /vsimem/5WQEEIVJM3.vrt
#   minmax: 0.000 0.05
#   SourceBand: 11
#   wkv: surface_ratio_of_upwelling_radiance_emerging_from_sea_water_to_downwelling_radiative_flux_in_air
#   valid_max: 25000
#   solar_irradiance: 1481.3671
#   name: Rrs_678
# Band : 12 angstrom
#   name: angstrom
#   dataType: 6
#   valid_min: -30000
#   long_name: Aerosol Angstrom exponent, 443 to 865 nm
#   standard_name: aerosol_angstrom_exponent
#   SourceFilename: /vsimem/5WQEEIVJM3.vrt
#   SourceBand: 12
#   valid_max: 5000
#   wkv: aerosol_angstrom_exponent
# Band : 13 aot_869
#   name: aot_869
#   dataType: 6
#   valid_min: 0
#   long_name: Aerosol optical thickness at 869 nm
#   standard_name: atmosphere_absorption_optical_thickness_due_to_ambient_aerosol
#   SourceFilename: /vsimem/5WQEEIVJM3.vrt
#   SourceBand: 13
#   valid_max: 30000
#   wkv: atmosphere_absorption_optical_thickness_due_to_ambient_aerosol
# Band : 14 chl_ocx
#   units: mg m^-3
#   name: chl_ocx
#   reference: O'Reilly, J.E., and 24 Coauthors, 2000: SeaWiFS Postlaunch Calibration and Validation Analyses, Part 3. NASA Tech. Memo. 2000-206892, Vol. 11, S.B. Hooker and E.R. Firestone, Eds., NASA Goddard Space Flight Center, 49 pp.; http://oceancolor.gsfc.nasa.gov/REPROCESSING/R2009/ocv6/
#   dataType: 6
#   valid_min: 0.001
#   long_name: Chlorophyll Concentration, OC3 Algorithm
#   standard_name: mass_concentration_chlorophyll_concentration_in_sea_water
#   SourceFilename: /vsimem/5WQEEIVJM3.vrt
#   SourceBand: 14
#   valid_max: 100
#   wkv: mass_concentration_chlorophyll_concentration_in_sea_water
# Band : 15 chlor_a
#   units: mg m^-3
#   name: chlor_a
#   reference: Hu, C., Lee Z., and Franz, B.A. (2012). Chlorophyll-a algorithms for oligotrophic oceans: A novel approach based on three-band reflectance difference, J. Geophys. Res., 117, C01011, doi:10.1029/2011JC007395.
#   dataType: 6
#   valid_min: 0.001
#   long_name: Chlorophyll Concentration, OCI Algorithm
#   standard_name: mass_concentration_chlorophyll_concentration_in_sea_water
#   SourceFilename: /vsimem/5WQEEIVJM3.vrt
#   SourceBand: 15
#   valid_max: 100
#   wkv: mass_concentration_chlorophyll_concentration_in_sea_water
# Band : 16 ipar
#   units: einstein m^-2 s^-1
#   colormap: jet
#   short_name: PAR
#   dataType: 6
#   long_name: Instantaneous Photosynthetically Available Radiation
#   standard_name: downwelling_photosynthetic_photon_radiance_in_sea_water
#   SourceFilename: /vsimem/5WQEEIVJM3.vrt
#   minmax: 0 80
#   SourceBand: 16
#   wkv: downwelling_photosynthetic_photon_radiance_in_sea_water
#   name: ipar
# Band : 17 l2_flags
#   name: l2_flags
#   long_name: Level-2 Processing Flags
#   dataType: 4
#   flag_masks: 1 2 4 8 16 32 64 128 256 512 1024 2048 4096 8192 16384 32768 65536 131072 262144 524288 1048576 2097152 4194304 8388608 16777216 33554432 67108864 134217728 268435456 536870912 1073741824 -2147483648
#   flag_meanings: ATMFAIL LAND PRODWARN HIGLINT HILT HISATZEN COASTZ SPARE STRAYLIGHT CLDICE COCCOLITH TURBIDW HISOLZEN SPARE LOWLW CHLFAIL NAVWARN ABSAER SPARE MAXAERITER MODGLINT CHLWARN ATMWARN SPARE SEAICE NAVFAIL FILTER SPARE SPARE HIPOL PRODFAIL SPARE
#   valid_min: -2147483648
#   SourceFilename: /vsimem/5WQEEIVJM3.vrt
#   SourceBand: 17
#   valid_max: 2147483647
# Band : 18 nflh
#   units: W m^-2 um^-1 sr^-1
#   name: nflh
#   reference: Behrenfeld, M.J., Westberry, T.K., Boss, E.S., O'Malley, R.T., Siegel, D.A., Wiggert, J.D., Franz, B.A., McClain, C.R., Feldman, G.C., Doney, S.C., Moore, J.K., Dall'Olmo, G., Milligan, A.J., Lima, I., and Mahowald, N.: Satellite-detected fluorescence reveals global physiology of ocean phytoplankton, Biogeosciences, 6, 779-794, doi:10.5194/bg-6-779-2009, 2009.
#   dataType: 6
#   long_name: Normalized Fluorescence Line Height
#   valid_min: -32353
#   SourceFilename: /vsimem/5WQEEIVJM3.vrt
#   SourceBand: 18
#   valid_max: 32353
# Band : 19 par
#   units: einstein m^-2 day^-1
#   name: par
#   reference: Frouin, R., Ligner, D.W., and Gautier, C., 1989: A Simple analytical formula to compute clear sky total and photosynthetically available solar irradiance at the ocean surface. J. Geophys. Res., 94, 9731-9742.
#   dataType: 6
#   valid_min: -32750
#   long_name: Photosynthetically Available Radiation, R. Frouin
#   standard_name: surface_downwelling_photosynthetic_photon_flux_in_air
#   SourceFilename: /vsimem/5WQEEIVJM3.vrt
#   SourceBand: 19
#   valid_max: -23286
#   wkv: surface_downwelling_photosynthetic_photon_flux_in_air
# Band : 20 pic
#   units: mol m^-3
#   name: pic
#   reference: Balch, W.M., Gordon, H.R., Bowler, B.C., Drapeau, D.T., and Booth, E.S. (2005), Calcium carbonate measurements in the surface global ocean based on Moderate-Resolution Imaging Spectroradiometer data, J. Geophys. Res., 110, C07001, doi:10.1029/2004JC002560; Gordon, H.R. Boynton, G.C., Balch, W.M., Groom, S.B., Harbour, D.S., Smyth, T.J., Retrieval of Coccolithophore Calcite Concentration from SeaWiFS Imagery, GRL, 28, 8, 1587-1590.
#   dataType: 6
#   valid_min: -32500
#   long_name: Calcite Concentration, Balch and Gordon
#   standard_name: mole_concentration_of_particulate_inorganic_carbon_in_sea_water
#   SourceFilename: /vsimem/5WQEEIVJM3.vrt
#   SourceBand: 20
#   valid_max: 30000
#   wkv: mole_concentration_of_particulate_inorganic_carbon_in_sea_water
# Band : 21 poc
#   units: mg m^-3
#   name: poc
#   reference: Stramski, D., et al. "Relationships between the surface concentration of particulate organic carbon and optical properties in the eastern South Pacific and eastern Atlantic Oceans." Biogeosciences 5.1 (2008): 171-201.
#   dataType: 6
#   valid_min: -32000
#   long_name: Particulate Organic Carbon, D. Stramski, 2007 (443/555 version)
#   standard_name: mole_concentration_of_particulate_organic_carbon_in_sea_water
#   SourceFilename: /vsimem/5WQEEIVJM3.vrt
#   SourceBand: 21
#   valid_max: -27000
#   wkv: mole_concentration_of_particulate_organic_carbon_in_sea_water
# Band : 22 latitude
#   units: degree_north
#   colormap: jet
#   short_name: latitude
#   dataType: 6
#   valid_min: -90
#   long_name: Latitude
#   standard_name: latitude
#   SourceFilename: /vsimem/5WQEEIVJM3.vrt
#   minmax: -90 90
#   SourceBand: 22
#   wkv: latitude
#   valid_max: 90
#   name: latitude
# Band : 23 longitude
#   units: degree_east
#   colormap: jet
#   short_name: longitude
#   dataType: 6
#   valid_min: -180
#   long_name: Longitude
#   standard_name: longitude
#   SourceFilename: /vsimem/5WQEEIVJM3.vrt
#   minmax: -180 180
#   SourceBand: 23
#   wkv: longitude
#   valid_max: 180
#   name: longitude
# Band : 24 swathmask
#   units: na
#   colormap: jet
#   short_name: swathmask
#   dataType: 1
#   PixelFunctionType: OnesPixelFunc
#   long_name: Swath mask
#   standard_name: swath_binary_mask
#   SourceFilename: /vsimem/5WQEEIVJM3.vrt
#   minmax: 0 1
#   SourceBand: 1
#   wkv: swath_binary_mask
#   name: swathmask
# ----------------------------------------
# Domain:[122 x 78]
# ----------------------------------------
# Projection:
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563]],
#     PRIMEM["Greenwich",0],
#     UNIT["degree",0.0174532925199433]]
# ----------------------------------------
# Corners (lon, lat):
# 	 (-86.30,  45.30)  (-85.20,  45.30)
# 	 (-86.30,  44.60)  (-85.20,  44.60)

# %%
test_img_1 = boreali_processing(test_img, wavelens2use, h, osw_mod='on') # Boreali-OSW processing
test_img_2 = boreali_processing(test_img, wavelens2use, h, osw_mod='off') # Boreali-bace processing 

show_it(test_img_1['chl'], name='Boreali OSW CHL / Aug 2012', limits=[0.,4.])
show_it(test_img_2['chl'], name='Boreali deep CHL / Aug 2012', limits=[0.,4.])


plt.figure()
plt.imshow(test_img['Rrs_667'])
plt.colorbar()
plt.show(test_img)
# Out:
# wavelen [412.0, 443.0, 469.0, 488.0, 531.0, 547.0, 555.0]
# R Name is  Rrs_
# Pixels x bands to process:  (3358, 7)
# launch shallow
# launch shallow
# launch shallow
# launch shallow
# spent:  2.92145395279
# wavelen [412.0, 443.0, 469.0, 488.0, 531.0, 547.0, 555.0]
# R Name is  Rrsw_
# Pixels x bands to process:  (3358, 7)
# launch deep
# launch deep
# launch deep
# launch deep
# spent:  1.51824593544
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
# Test img_oct path: ./data/A2014301181500.L2_LAC_OC.x.nc
# Test img_may path: ./data/A2014301181500.L2_LAC_OC.x.nc

# Bathymetry file path: ./data/michigan_lld.grd
# source: https://www.ngdc.noaa.gov/mgg/greatlakes/michigan.html
# units: meters
DATA_ROOT = 'data'

img_oct = Nansat(os.path.join(DATA_ROOT, 'A2014301181500.L2_LAC_OC.x.nc'))
img_may = Nansat(os.path.join(DATA_ROOT, 'A2014121184000.L2_LAC_OC.x.nc'))

bathymetry = Nansat(os.path.join(DATA_ROOT, 'michigan_lld.grd'))

dom = Domain('+proj=latlong +datum=WGS84 +ellps=WGS84 +no_defs', '-lle -86.3 44.6 -85.2 45.3 -ts 122 78')
# Each point is ~ 0.4 km (300x200)
# Each point is ~ 1.0 km (122x78)

img_oct.reproject(dom)
img_may.reproject(dom)

bathymetry.reproject(dom)
# Out:
# =>michigan.grd<=

# %%
#img_oct.write_figure('output/img_oct_rgb.png',bands=[1,8,10])
#Image('output/img_oct_rgb.png
img_may.write_figure('output/img_may_rgb_2.png',bands=['Rrs_667','Rrs_555','Rrs_443'], clim='hist', ratio=0.999)
rgb = plt.imread('output/img_may_rgb_2.png')
plt.figure(figsize=(10,7))
plt.imshow(rgb, interpolation='nearest')
# Out:
# <img src="data:image/png;base64,...">

# %%
# preparing of bottom field
h = bathymetry[1]
# all points there h >= 0 will marked as np.nan
h = np.where(h >= 0, np.nan, np.float32(h) * -1)
# the mask of land 
h_mask = np.where(np.isfinite(h), np.nan, np.array(1))

# the mask which shows 10 meters depth zone
h_10m = np.where(h <= 10, np.array(1), np.nan)
# Out:
# /home/artemm/Programs/Miniconda/miniconda2/envs/nansat/lib/python2.7/site-packages/ipykernel/__main__.py:9: RuntimeWarning: invalid value encountered in less_equal

# %%
def show_it(obj, name, color='jet', limits=None, z10='off', size=(9, 6), coord_grid='off'):
    plt.figure(figsize=size)
    plt.imshow(obj, clim=limits, cmap=color, interpolation='nearest')
    plt.colorbar()
    plt.title(name, y=1.08, fontsize=16)
    plt.tick_params(labelsize=14)

    if coord_grid == 'on':
        y = np.arange(0.0, 79.0, 79.0 / 7)
        y_labels = np.arange(45.3, 44.5, -0.1)
        x = np.arange(0.0, 123.0, 123.0 / 11)
        x_labels = np.arange(86.3, 85.2, -0.1)
        plt.yticks(y, y_labels)
        plt.xticks(x, x_labels)

    # black field is area which depth less than 10 meters
    if z10 == 'on': plt.imshow(h_10m, cmap='gray')
    plt.imshow(h_mask, cmap='Dark2')
    plt.grid(color='black')

# %%
# plotting of bottom field
# blue is water, green is land, black is zone of less than 10 meters depth
show_it(h, 'Bathymerty, m', color='Blues', z10='off', size=(12,8), limits=[0, 30])
# Out:
# <img src="data:image/png;base64,...">

# %%
# List of sets of bands  which were used to boreali processing:

wavelens_base = [412, 443, 469, 488, 531, 547, 555, 645, 667, 678]   # All MODIS channels
wavelens_blue_off = [443, 469, 488, 531, 547, 555, 645, 667, 678]    # Without 412 nm
wavelens_1x1km_bands = [412, 443, 488, 531, 645, 678]   # Only 1x1 km spatial resolution bands
wavelens_red_off = [412, 443, 469, 488, 531, 547, 555, 645, 667]    # Without 678 nm
wavelens_blueandred_off = [443, 469, 488, 531, 547, 555, 645, 667]   # Without 412 nm and 678 nm
wavelens_red_off_full = [412, 443, 469, 488, 531, 547, 555]
wavelens_1x1km_bands_2 = [443, 488, 531, 645, 678]   # Only 1x1 km spatial resolution bands

wavelens2use = wavelens_red_off_full

# %%
def boreali_processing(n_img, wavelens, h, bottom_type=0, osw_mod='on'):
    """
    :param n_img: Nansat img
    :param wavelen: nupy array (vector) of wave lenghts
    :param h: numpy array of bottom deph was got from michigan_lld.grd
    :param osw_mod: Need i to use OSW ?  
    :return: numpy array custom_n which contain Rrs, Rrsw and CPA data
    """
    cpa_limits = [0.01, 3, 
                  0.01, 1, 
                  0.01, 1, 10]
    
    b = Boreali('michigan', wavelens)
    theta = np.zeros_like(n_img[2])
    custom_n = Nansat(domain=n_img)
    band_rrs_numbers = list(map(lambda x: n_img._get_band_number('Rrs_' + str(x)), wavelens)) 
    
    for index in range(0, len(wavelens)):
        rrsw = n_img[band_rrs_numbers[index]] / (0.52 + 1.7 * n_img[band_rrs_numbers[index]])   
        custom_n.add_band(rrsw, parameters={'name': 'Rrsw_' + str(wavelens[index]),  
                                            'units': 'sr-1',
                                            'wavelength': wavelens[index]})
        
        # If we want to use OSW mod, we will need to add Rrs data in custom_n obj
        if osw_mod == 'on':
            custom_n.add_band(n_img[band_rrs_numbers[index]], parameters={'name': 'Rrs_' + str(wavelens[index]),
                                                                          'units': 'sr-1',
                                                                          'wavelength': wavelens[index]})
    # Creating of the mask
    # All pixels marked as -0.015534 in img will marked as 0.0 in the mask
    mask = np.where(n_img[2] != np.float(-0.015534), np.array(64.0), np.array(0.0)) 
    # Validation of mask according to bathymetry data.
    # If in the bathymetry pixel was marked as np.nan, in mask he will marked as 0.0
    # else nothing
    mask = np.where(np.isnan(h), np.array(0.), mask)
    # Adding of mask into custom_n obj
    custom_n.add_band(mask, parameters={'name' : 'mask'})
    
    # h is trigger for OWS processing mod. 
    # If want to star OSW we will need to add h to Boreali.process
    # else marked it as None
    if osw_mod == 'on': 
        depth = h
    else: 
        depth = None
    
    cpa = b.process(custom_n, cpa_limits,  mask=custom_n['mask'], depth=depth, theta=theta, threads=4)

    custom_n.add_band(array=cpa[0], parameters={'name': 'chl',
                                                'long_name': 'Chlorophyl-a',
                                                'units': 'mg m-3'})
    custom_n.add_band(array=cpa[1], parameters={'name': 'tsm',
                                                'long_name': 'Total suspended matter',
                                                'units': 'g m-3'})
    custom_n.add_band(array=cpa[2], parameters={'name': 'doc',
                                                        'long_name': 'Dissolved organic carbon',
                                                'units': 'gC m-3'})
    custom_n.add_band(array=cpa[3], parameters={'name': 'mse',
                                                'long_name': 'Root Mean Square Error',
                                                'units': 'sr-1'})
    custom_n.add_band(array=cpa[4], parameters={'name': 'mask',
                                                'long_name': 'L2 Boreali mask',
                                                'units': '1'})
    
    #   custom_n.export(final_path + obj.split('/')[-1] + 'cpa_OSW.nc')
    return custom_n

# %%
test_oct_1 = boreali_processing(img_oct, wavelens2use, h/1., osw_mod='on') # Boreali-OSW processing
test_oct_1a = boreali_processing(img_oct, wavelens2use, h/2., osw_mod='on') # Boreali-OSW processing
test_oct_2 = boreali_processing(img_oct, wavelens2use, h/1., osw_mod='off') # Boreali-bace processing 

show_it(test_oct_1['tsm'], name='Boreali OSW CHL / Oct 2014', limits=[0.,.2])
show_it(test_oct_1a['tsm'], name='Boreali deep CHL / Oct 2014', limits=[0.,.2])
show_it(test_oct_2['tsm'], name='Boreali deep CHL / Oct 2014', limits=[0.,.2])
# Out:
# wavelen [412.0, 443.0, 488.0, 531.0, 645.0, 678.0]
# R Name is  Rrs_
# Pixels x bands to process:  (3440, 6)
# launch shallow
# launch shallow
# launch shallow
# launch shallow
# spent:  1.69897890091
# wavelen [412.0, 443.0, 488.0, 531.0, 645.0, 678.0]
# R Name is  Rrs_
# Pixels x bands to process:  (3440, 6)
# launch shallow
# launch shallow
# launch shallow
# launch shallow
# spent:  1.74421811104
# wavelen [412.0, 443.0, 488.0, 531.0, 645.0, 678.0]
# R Name is  Rrsw_
# Pixels x bands to process:  (3440, 6)
# launch deep
# launch deep
# launch deep
# launch deep
# spent:  1.34239792824
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
factor = 0.8
test_may_1 = boreali_processing(img_may, wavelens2use, h * factor, osw_mod='on') # Boreali-OSW processing
test_may_2 = boreali_processing(img_may, wavelens2use, h * factor, osw_mod='off') # Boreali-bace processing 

show_it(test_may_1['tsm'], name='Boreali OSW TSM / May 2014', limits=[0.,.30])
show_it(test_may_2['tsm'], name='Boreali deep TSM / May 2014', limits=[0.,.30])
# Out:
# wavelen [412.0, 443.0, 488.0, 531.0, 645.0, 678.0]
# R Name is  Rrs_
# Pixels x bands to process:  (1134, 6)
# launch shallow
# launch shallow
# launch shallow
# launch shallow
# spent:  0.57720208168
# wavelen [412.0, 443.0, 488.0, 531.0, 645.0, 678.0]
# R Name is  Rrsw_
# Pixels x bands to process:  (1134, 6)
# launch deep
# launch deep
# launch deep
# launch deep
# spent:  0.381349086761
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
def get_r(obj, coords, r_type, wavelens):
    y, x = coords
    band_numbers = list(map(lambda x: obj._get_band_number(r_type + str(x)), wavelens))
    r_list = [obj[band][y][x] for band in band_numbers]
    return r_list


def plot_r(obj, wavelens, coords, r_type='Rrs_', size=(9, 6), title=None):
    y, x = coords
    r_list = get_r(obj, coords, r_type, wavelens)
    num_bands = range(0, len(r_list))

    plt.figure(figsize=size)
    plt.title('%s / %s / Point: (x: %d, y:%d) / Depth: %5.2f' % (title,r_type, x, y, h[y, x]))
    plt.tick_params(labelsize=14)
    plt.plot(num_bands, r_list)
    plt.xticks(num_bands, wavelens)
    plt.xlabel('wavelength, nm', fontsize=14)
    plt.ylabel('%s, sr^-1' % (r_type), fontsize=14)
    plt.grid(color='black')
    plt.ylim([0, 0.008])

# %%
def find_valid_points(coord_list):
    points = [] 
    for i in range(0, len(coord_list)):
        y,x = coord_list[i]
        if True not in np.isnan(h[y-1:y+2, x-1:x+2]) and y not in (0, 78) and x not in (0, 122):
            points.append(coord_list[i])
    return points

def negative_spectrum_filter(obj, pixels):
    positive_px = []
    for pixel in pixels:
        if obj['chl'][pixel[0], pixel[1]] != np.nan:
            flag = 1
            r = get_r(test1, pixel, 'Rrs_', wavelens_base)
            for i in r:
                if i < 0:
                    flag = 0
            if flag == 1: positive_px.append(pixel)

# We get a list of coordinates (tuple of (y,x) indexes of px) 
# of points which shallower then 10 m
coords = zip(*np.where(h_10m == 1)) 
# Checking that the pixel situated farther than 1 px (1 km) from the coast?
pixels = find_valid_points(coords)

# %%
def boreali_lm(obj, wavelens, h, coords, bottom_type=0, show='on', title=None, mod='michigan'):
    """
    :param wavelens: list.
    :param h: 2D array.
    :param coords: tuple. i, j 
    :param bottom_type: int.
    0 - sand; 1 - sargassum; 2 - silt; 3 - boodlea; 4 - limestone; 
    5 - enteromorpha; 6 - cladophora; 7 - chara; 8 - sand2; 9 - sand3; 10 - charasand;
    11 - cladforaosand; 12 - sandmichi; 13 - cladomichi; 
    """
    y, x = coords
    b = Boreali(mod, wavelens)
    model = b.get_homodel()
    theta = 0
    albedoType = bottom_type
    depth = float(h[y,x])
    #depth = 7
    albedo = b.get_albedo([albedoType])[0]

    cpa_limits = [0.01, 3,
                  0.01, 1,
                  0.01, 1, 10]

    r = get_r(obj, (y, x), 'Rrsw_', wavelens)
    c_deep = lm.get_c_deep(cpa_limits, model, [r], [theta], 4)[1]
    c_osw = lm.get_c_shal(cpa_limits, model, [r], [theta], [depth], [albedo], 4)[1]
    
    # backward case
    rrsw_deep = lm.get_rrsw_deep(model, c_deep[0:3], theta, len(wavelens))[1]
    rrsw_osw = lm.get_rrsw_shal(model, c_osw[0:3], theta, depth, albedo, len(wavelens))[1]
    rrsw_osw_mod = lm.get_rrsw_shal(model, np.array([0.5,0,0]), theta, depth, albedo, len(wavelens))[1]
    
    if show == 'on':
        print title
        print 'BOREALI DEEP: chl=%5.2f, tsm=%5.2f, doc=%5.2f, rmse=%5.2f' % tuple(c_deep)
        print 'BOREALI OSW: chl=%5.2f, tsm=%5.2f, doc=%5.2f, rmse=%5.2f' % tuple(c_osw)
        
        num_bands = range(0, len(r))

        plt.figure(figsize=(12,5))
        plt.title('%s / %s / Point: (x: %d, y:%d) / Depth: %5.2f' % (title,'Rrsw', x, y, depth))
        plt.tick_params(labelsize=14)
        plt.plot(num_bands, r, label='rrsw')
        plt.plot(num_bands, rrsw_osw, label='rrsw_osw')
        plt.plot(num_bands, rrsw_osw_mod, label='rrsw_osw_mod')
        plt.plot(num_bands, rrsw_deep, label='rrsw_deep')

        plt.xticks(num_bands, wavelens)
        plt.xlabel('wavelength, nm', fontsize=14)
        plt.ylabel('%s, sr^-1' % ('Rrsw_'), fontsize=14)
        plt.grid(color='black')
        plt.legend()
        plt.ylim([0, 0.016])
        # plot_r(obj, wavelens=wavelens, coords=(y, x), size=(10, 4), title='title')
    else:
        return c_osw, c_deep, depth

# %%
px = (43, 18)
boreali_lm(test_may_1, wavelens2use, h, px, bottom_type=0, title='May 2014')
#boreali_lm(test_oct_1, wavelens2use, h, px, bottom_type=0, title='October 2014')
# Out:
# May 2014
# BOREALI DEEP: chl= 0.42, tsm= 0.18, doc= 0.06, rmse= 0.00
# BOREALI OSW: chl= 0.29, tsm= 0.25, doc= 0.04, rmse= 0.00
# <img src="data:image/png;base64,...">

# %%
px = (45, 14)
boreali_lm(test_may_1, wavelens2use, h, px, bottom_type=0, title='May 2014')
#boreali_lm(test_oct_1, wavelens2use, h, px, bottom_type=0, title='October 2014')
# Out:
# May 2014
# BOREALI DEEP: chl= 0.58, tsm= 0.13, doc= 0.05, rmse= 0.00
# BOREALI OSW: chl= 0.91, tsm= 0.07, doc= 0.02, rmse= 0.00
# <img src="data:image/png;base64,...">

# %%
# %load_ext autoreload
# %autoreload 2

import os
from michigan_fuse.fusion import Fusion
import numpy as np
from ovl_plugins.fusion.fusion import fuse

# Paths to root directories for each sensor:
M_DATA_PATH = '/data/MODISa/LAC_OC'
S2_DATA_PATH = '/data/sentinel2a'
S3_DATA_PATH = '/data/sentinel3'

M_REPROJECTED_DATA_PATH = '/data/reprojected_data/MODISa/'
S2_REPROJECTED_DATA_PATH = '/data/reprojected_data/sentinel2/'


mfile = os.path.join(M_REPROJECTED_DATA_PATH, 'A2016187190000.L2_LAC_OC.x.nc_reprojected.nc')
sfile = os.path.join(S2_REPROJECTED_DATA_PATH, 'S2A_OPER_PRD_MSIL1C_PDMC_20160705T215730_R126_V20160705T164320_20160705T164320.SAFE_reprojected.nc')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
a = Fusion(mfile, sfile)
# Out:
# michigan_fuse/fusion.py:99: RuntimeWarning: invalid value encountered in greater
#   return hires_arr
# michigan_fuse/fusion.py:100: RuntimeWarning: invalid value encountered in less

# %%
a.fusion()
# Out:
# Creating training datasets from input data ...
# /home/amoiseev/Programs/Miniconda/envs/niersc/lib/python2.7/site-packages/ovl_plugins-0.1.42-py2.7.egg/ovl_plugins/fusion/fusion.py:98: RuntimeWarning: invalid value encountered in less
#   nnData[nnData < 0] = np.nan
# /home/amoiseev/Programs/Miniconda/envs/niersc/lib/python2.7/site-packages/ovl_plugins-0.1.42-py2.7.egg/ovl_plugins/fusion/fusion.py:99: RuntimeWarning: invalid value encountered in greater
#   nnData[nnData > 1] = np.nan
#  Number of training vectors: 1894
# OK!
# Training network in 20 iterations ...
# Train network
# ### -> RMSE
# 000 -> 0.176
# 001 -> 0.174
# 002 -> 0.174
# 003 -> 0.172
# 004 -> 0.172
# 005 -> 0.171
# 006 -> 0.170
# 007 -> 0.167
# 008 -> 0.166
# 009 -> 0.167
# 010 -> 0.165
# 011 -> 0.164
# 012 -> 0.164
# 013 -> 0.163
# 014 -> 0.162
# 015 -> 0.162
# 016 -> 0.161
# 017 -> 0.160
# 018 -> 0.160
# 019 -> 0.161
# Training network - OK!
# Saving network to file ... OK!
# Applying network in 7 threads...
# Feed 0 thread
# Feed 1 thread
# Feed 2 thread
# Feed 3 thread
# Feed 4 thread
# Feed 5 thread
# Feed 6 thread
# Apply network
# OK!
# Creating training datasets from input data ...  Number of training vectors: 1892
# OK!
# Training network in 20 iterations ...
# Train network
# ### -> RMSE
# 000 -> 0.167
# 001 -> 0.166
# 002 -> 0.166
# 003 -> 0.165
# 004 -> 0.164
# 005 -> 0.165
# 006 -> 0.164
# 007 -> 0.163
# 008 -> 0.163
# 009 -> 0.161
# 010 -> 0.161
# 011 -> 0.163
# 012 -> 0.160
# 013 -> 0.160
# 014 -> 0.160
# 015 -> 0.159
# 016 -> 0.159

# %%
def fusion(m_wavelengths='full'):
    bands = ['Rrs_%s' % wavelength for wavelength in a.wavelengths['modis']['1x1km_bands']]
    hires_rgb = []
    lores_rgb = []
    for rgb_band in bands:
        lores = a.loresfile[rgb_band]
        print lores[None]
        lores = lores[:2000, :2000]
        lores[a.negpix] = np.nan
        plt.figure()
        plt.imshow(lores)
        plt.show()
        lores_rgb.append(lores)
        hires_fused = fuse(a.hires, lores, network_name=rgb_band, iterations=20, threads=4, index=a.index)
#         hires_rgb.append(hires_fused)
#     return lores_rgb, hires_rgb

wl = a.wavelengths['modis']['full']
index = a.index
hires = a.hires
fusion()
# Out:
#  [[[ -1.55339995e-02  -1.55339995e-02   2.94600008e-03 ...,  -1.55339995e-02
#     -1.55339995e-02  -1.55339995e-02]
#   [  3.22400010e-03   3.22400010e-03   2.42800009e-03 ...,  -1.55339995e-02
#     -1.55339995e-02  -1.55339995e-02]
#   [  3.06600006e-03   2.72200000e-03   2.96399998e-03 ...,  -1.55339995e-02
#     -1.55339995e-02  -1.55339995e-02]
#   ...,
#   [  5.85999980e-04   9.20000020e-05   9.20000020e-05 ...,  -1.55339995e-02
#     -1.55339995e-02  -1.55339995e-02]
#   [  5.85999980e-04   6.25999994e-04   2.20000002e-04 ...,  -1.55339995e-02
#     -1.55339995e-02  -1.55339995e-02]
#   [  6.25999994e-04   7.52000022e-04   3.30000010e-04 ...,  -1.55339995e-02
#     -1.55339995e-02  -1.55339995e-02]]]
# <div id='a39d34ba-181a-4c0a-b7be-5096b067feb0'></div>
# Creating training datasets from input data ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-f1ac2dfd9913> in <module>()
#      19 index = a.index
#      20 hires = a.hires
# ---> 21 fusion()
#
# <ipython-input-52-f1ac2dfd9913> in fusion(m_wavelengths)
#      12         plt.show()
#      13         lores_rgb.append(lores)
# ---> 14         hires_fused = fuse(a.hires, lores, network_name=rgb_band, iterations=20, threads=4, index=a.index)
#      15 #         hires_rgb.append(hires_fused)
#      16 #     return lores_rgb, hires_rgb
#
# /home/amoiseev/Programs/Miniconda/envs/niersc/lib/python2.7/site-packages/ovl_plugins-0.1.42-py2.7.egg/ovl_plugins/fusion/fusion.pyc in fuse(hiresData, loresData, network_name, p, iterations, threads, nn_structure, index)
#      65     else:
#      66         print 'Creating training datasets from input data ... ',
# ---> 67         ds, nnMin, nnMax = create_training_dataset(hiresData, loresData, p, index)
#      68         print 'OK!'
#      69
#
# /home/amoiseev/Programs/Miniconda/envs/niersc/lib/python2.7/site-packages/ovl_plugins-0.1.42-py2.7.egg/ovl_plugins/fusion/fusion.pyc in create_training_dataset(hiresData, loresData, p, index)
#     135             maximum values of actual satellite data
#     136     '''
# --> 137     nnData, nnGPI, nnMin, nnMax = scale_training_data(hiresData, loresData, p)
#     138
#     139     # create training dataset with N inputs and 1 output
#
# /home/amoiseev/Programs/Miniconda/envs/niersc/lib/python2.7/site-packages/ovl_plugins-0.1.42-py2.7.egg/ovl_plugins/fusion/fusion.pyc in scale_training_data(hiresData, loresData, p)
#      87     ''' Scale input data to 0-1 range '''
#      88     # stack input/output data
# ---> 89     nnData = np.vstack([hiresData, loresData[None]])
#      90     gpi = np.isfinite(nnData.sum(axis=0))
#      91
#
# /home/amoiseev/Programs/Miniconda/envs/niersc/lib/python2.7/site-packages/numpy/core/shape_base.pyc in vstack(tup)
#     232
#     233     """
# --> 234     return _nx.concatenate([atleast_2d(_m) for _m in tup], 0)
#     235
#     236 def hstack(tup):
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.imshow(a.hires[2])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from nansat import Nansat
n = Nansat('/data/reprojected_data/MODISa/A2016187190000.L2_LAC_OC.x.nc_reprojected.nc')
n
# Out:
# ----------------------------------------
# /data/reprojected_data/MODISa/A2016187190000.L2_LAC_OC.x.nc_reprojected.nc
# ----------------------------------------
# Mapper: generic
# ----------------------------------------
# Band : 1 index
#   _FillValue: -2147483647
#   grid_mapping: crs
#   name: index
#   dataType: 5
#   long_name: GDAL Band Number 1
#   SourceFilename: NETCDF:"/data/reprojected_data/MODISa/A2016187190000.L2_LAC_OC.x.nc_reprojected.nc":index1
#   SourceBand: 1
#   wkv:
# Band : 2 Rrs_412
#   _FillValue: 9.96921e+36
#   name: Rrs_412
#   dataType: 6
#   long_name: GDAL Band Number 2
#   SourceFilename: NETCDF:"/data/reprojected_data/MODISa/A2016187190000.L2_LAC_OC.x.nc_reprojected.nc":Rrs_4122
#   SourceBand: 1
#   wkv:
# Band : 3 Rrs_443
#   _FillValue: 9.96921e+36
#   name: Rrs_443
#   dataType: 6
#   long_name: GDAL Band Number 3
#   SourceFilename: NETCDF:"/data/reprojected_data/MODISa/A2016187190000.L2_LAC_OC.x.nc_reprojected.nc":Rrs_4433
#   SourceBand: 1
#   wkv:
# Band : 4 Rrs_488
#   _FillValue: 9.96921e+36
#   name: Rrs_488
#   dataType: 6
#   long_name: GDAL Band Number 4
#   SourceFilename: NETCDF:"/data/reprojected_data/MODISa/A2016187190000.L2_LAC_OC.x.nc_reprojected.nc":Rrs_4884
#   SourceBand: 1
#   wkv:
# Band : 5 Rrs_531
#   _FillValue: 9.96921e+36
#   name: Rrs_531
#   dataType: 6
#   long_name: GDAL Band Number 5
#   SourceFilename: NETCDF:"/data/reprojected_data/MODISa/A2016187190000.L2_LAC_OC.x.nc_reprojected.nc":Rrs_5315
#   SourceBand: 1
#   wkv:
# Band : 6 Rrs_555
#   _FillValue: 9.96921e+36
#   name: Rrs_555
#   dataType: 6
#   long_name: GDAL Band Number 6
#   SourceFilename: NETCDF:"/data/reprojected_data/MODISa/A2016187190000.L2_LAC_OC.x.nc_reprojected.nc":Rrs_5556
#   SourceBand: 1
#   wkv:
# Band : 7 Rrs_645
#   _FillValue: 9.96921e+36
#   name: Rrs_645
#   dataType: 6
#   long_name: GDAL Band Number 7
#   SourceFilename: NETCDF:"/data/reprojected_data/MODISa/A2016187190000.L2_LAC_OC.x.nc_reprojected.nc":Rrs_6457
#   SourceBand: 1
#   wkv:
# Band : 8 Rrs_667
#   _FillValue: 9.96921e+36
#   name: Rrs_667
#   dataType: 6
#   long_name: GDAL Band Number 8
#   SourceFilename: NETCDF:"/data/reprojected_data/MODISa/A2016187190000.L2_LAC_OC.x.nc_reprojected.nc":Rrs_6678
#   SourceBand: 1
#   wkv:
# Band : 9 Rrs_678
#   _FillValue: 9.96921e+36
#   name: Rrs_678
#   dataType: 6
#   long_name: GDAL Band Number 9
#   SourceFilename: NETCDF:"/data/reprojected_data/MODISa/A2016187190000.L2_LAC_OC.x.nc_reprojected.nc":Rrs_6789
#   SourceBand: 1
#   wkv:
# ----------------------------------------
# Domain:[122 x 78]
# ----------------------------------------
# Projection:
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563]],
#     PRIMEM["Greenwich",0],
#     UNIT["degree",0.0174532925199433]]
# ----------------------------------------
# Corners (lon, lat):
# 	 (-86.30,  45.30)  (-85.20,  45.30)
# 	 (-86.30,  44.60)  (-85.20,  44.60)

# %%
nn = Nansat('/data/reprojected_data/sentinel2/S2A_OPER_PRD_MSIL1C_PDMC_20160705T215730_R126_V20160705T164320_20160705T164320.SAFE_reprojected.nc')

# %%
# %matplotlib nbagg
plt.figure(figsize=(12,8))
plt.imshow(nn[2])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1200">
