# %%
username = 'korvinos'
password = 'EyXn1kKjclxymEmOsmzV'
source = 'https://scihub.copernicus.eu/dhus'

first_day = "20150623" # date of launching sentinel2a

# %%
from sentinelsat.sentinel import SentinelAPI, get_coordinates
from datetime import date

# %%
api = SentinelAPI(username, password, source)

result = api.query(area=get_coordinates('michigan.geojson'),
                   initial_date="20150623", platformname="Sentinel-2")

# %%
# Out:
# [{u'date': [{u'content': u'2016-12-19T23:09:56.89Z',
#     u'name': u'ingestiondate'},
#    {u'content': u'2016-12-19T16:37:02.026Z', u'name': u'beginposition'},
#    {u'content': u'2016-12-19T16:37:02.026Z', u'name': u'endposition'}],
#   u'double': {u'content': u'75.8312', u'name': u'cloudcoverpercentage'},
#   u'id': u'5c5a5ae3-9fcf-42b5-bfdc-fbd9f2c1cbb4',
#   u'int': [{u'content': u'7802', u'name': u'orbitnumber'},
#    {u'content': u'83', u'name': u'relativeorbitnumber'}],
#   u'link': [{u'href': u"https://scihub.copernicus.eu/dhus/odata/v1/Products('5c5a5ae3-9fcf-42b5-bfdc-fbd9f2c1cbb4')/$value"},
#    {u'href': u"https://scihub.copernicus.eu/dhus/odata/v1/Products('5c5a5ae3-9fcf-42b5-bfdc-fbd9f2c1cbb4')/",
#     u'rel': u'alternative'},
#    {u'href': u"https://scihub.copernicus.eu/dhus/odata/v1/Products('5c5a5ae3-9fcf-42b5-bfdc-fbd9f2c1cbb4')/Products('Quicklook')/$value",
#     u'rel': u'icon'}],
# ...
